# %%
with open("sample.txt", "w") as f:
    f.write("Name Age Marks\n")
    f.write("anushka 21 85\n")
    f.write("Anu 22 90\n")

# %%
with open("sample.txt", "r") as f:
    print(f.read())
# Out:
# Name Age Marks
# anushka 21 85
# Anu 22 90

# %%
with open("example.txt") as f:
    print(f.read())
# Out:
# Machine Learning
# Signal Processing
# AI
